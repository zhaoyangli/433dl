# %%
import collections
import math
import os
import shutil
import pandas as pd
import torch
import torchvision
from torch import nn
from d2l import torch as d2l
import time

import os
import shutil
import collections
import math
import time
import torchvision
import torch
import torch.nn as nn
import torch.utils.data

import datetime

# %%
import torch
from torch import nn

# VGG模型定义
def vgg_block(num_convs, in_channels, out_channels):
    layers = []
    for _ in range(num_convs):
        layers.append(nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1))
        layers.append(nn.ReLU())
        in_channels = out_channels
    layers.append(nn.MaxPool2d(kernel_size=2, stride=2))
    return nn.Sequential(*layers)

conv_arch = [(1, 64), (1, 128), (2, 256), (2, 512), (2, 512)]

def vgg(conv_arch):
    conv_blks = []
    in_channels = 3  # CIFAR-10是3通道（RGB）图像
    for (num_convs, out_channels) in conv_arch:
        conv_blks.append(vgg_block(num_convs, in_channels, out_channels))
        in_channels = out_channels

    return nn.Sequential(
        *conv_blks, nn.Flatten(),
        nn.Linear(out_channels * 1 * 1, 4096),  # 调整全连接层的输入大小
        nn.ReLU(), nn.Dropout(0.5),
        nn.Linear(4096, 4096), nn.ReLU(), nn.Dropout(0.5),
        nn.Linear(4096, 10))  # CIFAR-10有10个类别

# 使用更小的VGG架构
conv_arch = ((1, 64), (1, 128), (2, 256), (2, 512), (2, 512))
ratio = 4
small_conv_arch = [(pair[0], pair[1] // ratio) for pair in conv_arch]
net = vgg(conv_arch)

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.optim
import time
import matplotlib.pyplot as plt

from torch.utils.data import DataLoader, random_split


from d2l import torch as d2l  # 确保已经安装了 d2l 包


if torch.cuda.is_available():
    devices = [torch.device('cuda')]
    print(f"Training on {torch.cuda.get_device_name(0)}")
else:
    devices = [torch.device('cpu')]
    print("Training on CPU")


# 数据预处理
transform_train = transforms.Compose([
    transforms.Resize(40),
    transforms.RandomResizedCrop(32, scale=(0.64, 1.0), ratio=(1.0, 1.0)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize([0.4914, 0.4822, 0.4465], [0.2023, 0.1994, 0.2010])
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize([0.4914, 0.4822, 0.4465], [0.2023, 0.1994, 0.2010])
])
batch_size = 128

# 加载 CIFAR-10 数据集
test_ds = torchvision.datasets.CIFAR10(root='../data', train=False, download=True, transform=transform_test)

# 加载 CIFAR-10 训练集
full_train_ds = torchvision.datasets.CIFAR10(root='../data', train=True, download=True, transform=transform_train)

# 分割训练集和验证集
valid_ratio = 0.1  # 比如，使用 10% 的数据作为验证集
num_train = len(full_train_ds)
num_valid = int(num_train * valid_ratio)
train_ds, valid_ds = random_split(full_train_ds, [num_train - num_valid, num_valid])

# 创建 DataLoader
train_iter = DataLoader(train_ds, batch_size=batch_size, shuffle=True, num_workers=2)
valid_iter = DataLoader(valid_ds, batch_size=batch_size, shuffle=False, num_workers=2)


# 定义数据加载器
train_iter = torch.utils.data.DataLoader(train_ds, batch_size=batch_size, shuffle=True, num_workers=2)
test_iter = torch.utils.data.DataLoader(test_ds, batch_size=batch_size, shuffle=False, num_workers=2)
valid_ratio = 0.1
# 其余定义模型和训练的代码保持不变...
valid_iter = torch.utils.data.DataLoader(valid_ds, batch_size, shuffle=False,
                                         drop_last=True)

test_iter = torch.utils.data.DataLoader(test_ds, batch_size, shuffle=False,
                                        drop_last=False)
def get_net():
    num_classes = 10
    net = d2l.resnet18(num_classes, 3)
    return net

loss = nn.CrossEntropyLoss(reduction="none")

def train(net, train_iter, valid_iter, num_epochs, lr, wd, devices, lr_period,
          lr_decay):
    trainer = torch.optim.SGD(net.parameters(), lr=lr, momentum=0.9,
                              weight_decay=wd)
    scheduler = torch.optim.lr_scheduler.StepLR(trainer, lr_period, lr_decay)
    num_batches, timer = len(train_iter), d2l.Timer()
    legend = ['train loss', 'train acc']
    if valid_iter is not None:
        legend.append('valid acc')
    # animator = d2l.Animator(xlabel='epoch', xlim=[1, num_epochs],
    #                         legend=legend)
    net = nn.DataParallel(net, device_ids=devices).to(devices[0])
    train_loss_list, train_acc_list, valid_acc_list = [], [], []
    total_time = 0
    for epoch in range(num_epochs):
        net.train()
        metric = d2l.Accumulator(3)
        start = time.time()
        for i, (features, labels) in enumerate(train_iter):
            timer.start()
            l, acc = d2l.train_batch_ch13(net, features, labels.to(devices[0]), loss, trainer, devices)
            metric.add(l, acc, labels.shape[0])
            timer.stop()
            # if (i + 1) % (num_batches // 5) == 0 or i == num_batches - 1:
                # animator.add(epoch + (i + 1) / num_batches,
                #              (metric[0] / metric[2], metric[1] / metric[2],
                #               None))
        train_loss, train_acc = metric[0] / metric[2], metric[1] / metric[2]                          
        epoch_time = time.time() - start
        total_time += epoch_time
        # print(f'Epoch {epoch + 1}, Loss {metric[0] / metric[2]:.3f}, Train acc {metric[1] / metric[2]:.3f}, Time {timer.sum():.1f} sec')
        if valid_iter is not None:
            valid_acc = d2l.evaluate_accuracy_gpu(net, valid_iter)
            # animator.add(epoch + 1, (None, None, valid_acc))
        print(f"{epoch+1}/{num_epochs} - {epoch_time:.0f}s - loss: {train_loss:.4f} - accuracy: {train_acc:.4f} - val_accuracy: {valid_acc:.4f} - {epoch_time:.0f}s/epoch - {timer.avg():.0f}ms/step")
        scheduler.step()
        train_loss_list.append(train_loss)
        train_acc_list.append(train_acc)
        valid_acc_list.append(valid_acc)
    measures = (f'train loss {metric[0] / metric[2]:.3f}',f'train acc {metric[1] / metric[2]:.3f}')
    # if valid_iter is not None:
    #     measures += f', valid acc {valid_acc:.3f}'
    print(f'Time {total_time:.1f} sec')
    # print(measures + f'\n{metric[2] * num_epochs / timer.sum():.1f}'
    #       f' examples/sec on {str(devices)}')
    # 保存训练图表
    # save_dir = 'training_plots'
    # os.makedirs(save_dir, exist_ok=True)
    # plot_filename = f"{save_dir}/train_plot_{noise_type}_{noise_level}.png"
    # plt.savefig(plot_filename)
    # plt.close()

    # 绘制训练图表
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(range(1, num_epochs + 1), train_loss_list, label='train_loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Training Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(range(1, num_epochs + 1), train_acc_list, label='train_acc')
    plt.plot(range(1, num_epochs + 1), valid_acc_list, label='valid_acc')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.legend()

    # 保存训练图表
    current_time = datetime.datetime.now().strftime('%Y%m%d_%H%M%S')
    save_dir = f'training_plots'
    os.makedirs(save_dir, exist_ok=True)
    plot_filename = f"{save_dir}/{current_time}_train_plot_{noise_type}_{noise_level}.png"
    plt.savefig(plot_filename)
    plt.close()

# devices, num_epochs, lr, wd = d2l.try_all_gpus(), 100, 2e-4, 5e-4
# lr_period, lr_decay, net = 4, 0.9, get_net()

# devices, num_epochs, lr, wd = d2l.try_all_gpus(), 100, 0.05, 5e-4
# lr_period, lr_decay, net = 50, 0.1, get_net()

# devices, num_epochs, lr, wd = d2l.try_all_gpus(), 50, 2e-4, 5e-4
# lr_period, lr_decay, net = 4, 0.9, get_net()
# # devices, num_epochs, lr, wd = d2l.try_all_gpus(), 100, 0.05, 5e-4
# # lr_period, lr_decay, net = 50, 0.1, get_net()
# train(net, train_iter, valid_iter, num_epochs, lr, wd, devices, lr_period,
#       lr_decay)
# Out:
# Training on NVIDIA GeForce GTX 1660 Ti
# Files already downloaded and verified
# Files already downloaded and verified

# %%
import torch
import numpy as np
import random

def add_noise_to_labels(labels, noise_ratio, noise_type='symmetric', num_classes=10):
    if noise_type not in ['symmetric', 'asymmetric']:
        raise ValueError("noise_type should be 'symmetric' or 'asymmetric'")

    noisy_labels = labels.clone()
    n = len(labels)

    # 对称噪声
    if noise_type == 'symmetric':
        for i in range(n):
            if random.random() < noise_ratio:
                noisy_labels[i] = random.choice([l for l in range(num_classes) if l != labels[i]])

    # 非对称噪声
    elif noise_type == 'asymmetric':
        print("asy: ", n, " ", noise_ratio)
        # CIFAR-10 specific label mapping
        mapping = {9: 1, 2: 0, 4: 7, 3: 5, 5: 3}
        for i in range(n):
            if random.random() < noise_ratio and labels[i].item() in mapping:
                # print("change")
                noisy_labels[i] = mapping[labels[i].item()]

    return noisy_labels
    
def verify_noise(original_labels, noisy_labels):
    assert len(original_labels) == len(noisy_labels), "Length of original and noisy labels must be equal"
    changed = (original_labels != noisy_labels).sum().item()
    total = len(original_labels)
    noise_ratio = changed / total
    return noise_ratio

# 假设 labels 是一个 PyTorch 张量，包含 CIFAR 数据集的标签

# 提取训练集的标签
original_labels = torch.tensor([full_train_ds[i][1] for i in range(len(full_train_ds))])

# 添加噪声
noise_ratio = 0.8  # 例如，添加 30% 的噪声
noisy_labels = add_noise_to_labels(original_labels, noise_ratio, noise_type='symmetric')

# 验证噪声添加
actual_noise_ratio = verify_noise(original_labels, noisy_labels)
print(f"Actual noise ratio: {actual_noise_ratio}")
print("Some original labels:", original_labels[:10])
print("Corresponding noisy labels (symmetric):", noisy_labels[:10])
# 假设 original_labels 和 noisy_labels 分别是原始和带噪声的标签
# 定义非对称噪声的映射关系
asymmetric_mapping = {9: 1, 2: 0, 4: 7, 3: 5, 5: 3}

def calculate_asymmetric_noise_ratio(original_labels, noisy_labels, mapping):
    """计算实际的非对称噪声比例"""
    n = len(original_labels)
    actual_changes = 0
    potential_changes = 0

    for i in range(n):
        if original_labels[i].item() in mapping:
            potential_changes += 1
            if noisy_labels[i].item() == mapping[original_labels[i].item()]:
                actual_changes += 1

    if potential_changes == 0:
        return 0
    else:
        return actual_changes / potential_changes


noisy_labels_a = add_noise_to_labels(original_labels, noise_ratio, noise_type='asymmetric')
# 检查原始标签和噪声标签是否有差异
print("Some original labels:", original_labels[:10])
print("Corresponding noisy labels (asymmetric):", noisy_labels_a[:10])


# 计算实际的非对称噪声比例
actual_asymmetric_noise_ratio = calculate_asymmetric_noise_ratio(original_labels, noisy_labels_a, asymmetric_mapping)
print(f"Actual asymmetric noise ratio: {actual_asymmetric_noise_ratio}")
# Out:
# Actual noise ratio: 0.80064
# Some original labels: tensor([6, 9, 9, 4, 1, 1, 2, 7, 8, 3])
# Corresponding noisy labels (symmetric): tensor([5, 1, 7, 3, 1, 7, 7, 4, 6, 8])
# asy:  50000   0.8
# Some original labels: tensor([6, 9, 9, 4, 1, 1, 2, 7, 8, 3])
# Corresponding noisy labels (asymmetric): tensor([6, 1, 1, 7, 1, 1, 0, 7, 8, 3])
# Actual asymmetric noise ratio: 0.80064

# %%
def run_train_harness(noise_level=0.0, noise_type='symmetric'):
    # 重新加载数据集以避免标签被多次修改
    full_train_ds = torchvision.datasets.CIFAR10(root='../data', train=True, download=True, transform=transform_train)
    original_labels = torch.tensor(full_train_ds.targets)

    # 应用噪声
    if noise_level > 0:
        noisy_labels = add_noise_to_labels(original_labels, noise_level, noise_type)
        full_train_ds.targets = noisy_labels.tolist()

    # 分割训练集和验证集
    num_train = len(full_train_ds)
    num_valid = int(num_train * valid_ratio)
    train_ds, valid_ds = random_split(full_train_ds, [num_train - num_valid, num_valid])

    # 创建 DataLoader
    train_iter = DataLoader(train_ds, batch_size=batch_size, shuffle=True, num_workers=2)
    valid_iter = DataLoader(valid_ds, batch_size=batch_size, shuffle=False, num_workers=2)
    
    devices, num_epochs, lr, wd = d2l.try_all_gpus(), 40, 2e-4, 5e-4
    lr_period, lr_decay = 4, 0.9
    net = vgg(small_conv_arch)

    train(net, train_iter, valid_iter, num_epochs, lr, wd, devices, lr_period, lr_decay)
    

# # 训练没有噪声的模型
print(f"####### Training model with 0 noise level: ########")
run_train_harness(0, 'symmetric')
print("\n\n\n")

# 用不同的噪声水平和类型训练模型
# noise_levels = [0.1, 0.3, 0.5, 0.8]
# noise_types = ['symmetric', 'asymmetric']

# for noise_type in noise_types:
#     for noise_level in noise_levels:
#         print(f"####### Training with {noise_type} noise level: {noise_level} ########")
#         run_train_harness(noise_level, noise_type)
#         print("\n\n\n")
# Out:
# ####### Training model with 0 noise level: ########
# Files already downloaded and verified
# 1/40 - 14s - loss: 2.3040 - accuracy: 0.0966 - val_accuracy: 0.1018 - 14s/epoch - 0ms/step
# 2/40 - 14s - loss: 2.3039 - accuracy: 0.0974 - val_accuracy: 0.0930 - 14s/epoch - 0ms/step
# 3/40 - 15s - loss: 2.2922 - accuracy: 0.1116 - val_accuracy: 0.1998 - 15s/epoch - 0ms/step
# 4/40 - 14s - loss: 1.9706 - accuracy: 0.2160 - val_accuracy: 0.2610 - 14s/epoch - 0ms/step
# 5/40 - 15s - loss: 1.7474 - accuracy: 0.3112 - val_accuracy: 0.3650 - 15s/epoch - 0ms/step
# 6/40 - 15s - loss: 1.5471 - accuracy: 0.4061 - val_accuracy: 0.4100 - 15s/epoch - 0ms/step
# 7/40 - 15s - loss: 1.3912 - accuracy: 0.4850 - val_accuracy: 0.5460 - 15s/epoch - 0ms/step
# 8/40 - 15s - loss: 1.2343 - accuracy: 0.5556 - val_accuracy: 0.5666 - 15s/epoch - 0ms/step
# 9/40 - 15s - loss: 1.1122 - accuracy: 0.6052 - val_accuracy: 0.6188 - 15s/epoch - 0ms/step
# 10/40 - 15s - loss: 1.0498 - accuracy: 0.6300 - val_accuracy: 0.6006 - 15s/epoch - 0ms/step
# 11/40 - 15s - loss: 0.9734 - accuracy: 0.6613 - val_accuracy: 0.6584 - 15s/epoch - 0ms/step
# 12/40 - 15s - loss: 0.9135 - accuracy: 0.6846 - val_accuracy: 0.6584 - 15s/epoch - 0ms/step
# 13/40 - 15s - loss: 0.8593 - accuracy: 0.7019 - val_accuracy: 0.6934 - 15s/epoch - 0ms/step
# 14/40 - 15s - loss: 0.8271 - accuracy: 0.7132 - val_accuracy: 0.7054 - 15s/epoch - 0ms/step
# 15/40 - 15s - loss: 0.7904 - accuracy: 0.7284 - val_accuracy: 0.7038 - 15s/epoch - 0ms/step
# 16/40 - 15s - loss: 0.7654 - accuracy: 0.7364 - val_accuracy: 0.7116 - 15s/epoch - 0ms/step
# 17/40 - 15s - loss: 0.7221 - accuracy: 0.7504 - val_accuracy: 0.7264 - 15s/epoch - 0ms/step
# 18/40 - 15s - loss: 0.6980 - accuracy: 0.7594 - val_accuracy: 0.7350 - 15s/epoch - 0ms/step
# 19/40 - 15s - loss: 0.6744 - accuracy: 0.7672 - val_accuracy: 0.7354 - 15s/epoch - 0ms/step
# 20/40 - 15s - loss: 0.6596 - accuracy: 0.7722 - val_accuracy: 0.7404 - 15s/epoch - 0ms/step
# 21/40 - 15s - loss: 0.6299 - accuracy: 0.7818 - val_accuracy: 0.7424 - 15s/epoch - 0ms/step
# 22/40 - 15s - loss: 0.6179 - accuracy: 0.7864 - val_accuracy: 0.7294 - 15s/epoch - 0ms/step
# 23/40 - 15s - loss: 0.5902 - accuracy: 0.7971 - val_accuracy: 0.7488 - 15s/epoch - 0ms/step
# 24/40 - 15s - loss: 0.5883 - accuracy: 0.7955 - val_accuracy: 0.7516 - 15s/epoch - 0ms/step
# 25/40 - 15s - loss: 0.5618 - accuracy: 0.8060 - val_accuracy: 0.7426 - 15s/epoch - 0ms/step
# 26/40 - 15s - loss: 0.5463 - accuracy: 0.8114 - val_accuracy: 0.7484 - 15s/epoch - 0ms/step
# 27/40 - 15s - loss: 0.5364 - accuracy: 0.8150 - val_accuracy: 0.7616 - 15s/epoch - 0ms/step
# 28/40 - 15s - loss: 0.5250 - accuracy: 0.8197 - val_accuracy: 0.7426 - 15s/epoch - 0ms/step
# 29/40 - 15s - loss: 0.5065 - accuracy: 0.8276 - val_accuracy: 0.7576 - 15s/epoch - 0ms/step
# 30/40 - 15s - loss: 0.4987 - accuracy: 0.8283 - val_accuracy: 0.7600 - 15s/epoch - 0ms/step
# 31/40 - 14s - loss: 0.4837 - accuracy: 0.8311 - val_accuracy: 0.7636 - 14s/epoch - 0ms/step
# 32/40 - 14s - loss: 0.4773 - accuracy: 0.8351 - val_accuracy: 0.7860 - 14s/epoch - 0ms/step
# 33/40 - 15s - loss: 0.4579 - accuracy: 0.8432 - val_accuracy: 0.7676 - 15s/epoch - 0ms/step
# 34/40 - 17s - loss: 0.4476 - accuracy: 0.8451 - val_accuracy: 0.7804 - 17s/epoch - 0ms/step
# 35/40 - 15s - loss: 0.4403 - accuracy: 0.8472 - val_accuracy: 0.7706 - 15s/epoch - 0ms/step
# 36/40 - 15s - loss: 0.4286 - accuracy: 0.8524 - val_accuracy: 0.7734 - 15s/epoch - 0ms/step
# 37/40 - 15s - loss: 0.4166 - accuracy: 0.8557 - val_accuracy: 0.7754 - 15s/epoch - 0ms/step
# 38/40 - 15s - loss: 0.4092 - accuracy: 0.8576 - val_accuracy: 0.7818 - 15s/epoch - 0ms/step
# 39/40 - 15s - loss: 0.4009 - accuracy: 0.8619 - val_accuracy: 0.7920 - 15s/epoch - 0ms/step
# 40/40 - 15s - loss: 0.3906 - accuracy: 0.8656 - val_accuracy: 0.7780 - 15s/epoch - 0ms/step
# Time 593.3 sec

# %%
noise_types = ['symmetric', 'asymmetric']
for noise_type in noise_types:
    noise_level = 0.1
    print(f"####### Training with {noise_type} noise level: {noise_level} ########")
    run_train_harness(noise_level, noise_type)
    print("\n\n\n")
# Out:
# ####### Training with symmetric noise level: 0.1 ########
# Files already downloaded and verified
# 1/40 - 15s - loss: 2.3041 - accuracy: 0.0989 - val_accuracy: 0.0948 - 15s/epoch - 0ms/step
# 2/40 - 15s - loss: 2.3039 - accuracy: 0.0996 - val_accuracy: 0.0980 - 15s/epoch - 0ms/step
# 3/40 - 14s - loss: 2.3035 - accuracy: 0.1016 - val_accuracy: 0.1060 - 14s/epoch - 0ms/step
# 4/40 - 15s - loss: 2.3035 - accuracy: 0.1014 - val_accuracy: 0.0982 - 15s/epoch - 0ms/step
# 5/40 - 15s - loss: 2.3035 - accuracy: 0.0988 - val_accuracy: 0.0930 - 15s/epoch - 0ms/step
# 6/40 - 15s - loss: 2.2356 - accuracy: 0.1398 - val_accuracy: 0.1774 - 15s/epoch - 0ms/step
# 7/40 - 15s - loss: 2.0249 - accuracy: 0.2124 - val_accuracy: 0.2632 - 15s/epoch - 0ms/step
# 8/40 - 15s - loss: 1.9046 - accuracy: 0.2855 - val_accuracy: 0.3336 - 15s/epoch - 0ms/step
# 9/40 - 15s - loss: 1.7588 - accuracy: 0.3640 - val_accuracy: 0.4148 - 15s/epoch - 0ms/step
# 10/40 - 15s - loss: 1.6672 - accuracy: 0.4186 - val_accuracy: 0.4776 - 15s/epoch - 0ms/step
# 11/40 - 15s - loss: 1.5521 - accuracy: 0.4722 - val_accuracy: 0.4814 - 15s/epoch - 0ms/step
# 12/40 - 15s - loss: 1.4725 - accuracy: 0.5176 - val_accuracy: 0.5366 - 15s/epoch - 0ms/step
# 13/40 - 15s - loss: 1.4028 - accuracy: 0.5479 - val_accuracy: 0.5720 - 15s/epoch - 0ms/step
# 14/40 - 15s - loss: 1.3452 - accuracy: 0.5742 - val_accuracy: 0.5662 - 15s/epoch - 0ms/step
# 15/40 - 15s - loss: 1.2991 - accuracy: 0.5932 - val_accuracy: 0.5808 - 15s/epoch - 0ms/step
# 16/40 - 15s - loss: 1.2604 - accuracy: 0.6098 - val_accuracy: 0.5960 - 15s/epoch - 0ms/step
# 17/40 - 15s - loss: 1.2186 - accuracy: 0.6282 - val_accuracy: 0.6192 - 15s/epoch - 0ms/step
# 18/40 - 14s - loss: 1.1897 - accuracy: 0.6411 - val_accuracy: 0.6232 - 14s/epoch - 0ms/step
# 19/40 - 15s - loss: 1.1630 - accuracy: 0.6513 - val_accuracy: 0.6276 - 15s/epoch - 0ms/step
# 20/40 - 15s - loss: 1.1471 - accuracy: 0.6574 - val_accuracy: 0.6546 - 15s/epoch - 0ms/step
# 21/40 - 15s - loss: 1.1161 - accuracy: 0.6692 - val_accuracy: 0.6618 - 15s/epoch - 0ms/step
# 22/40 - 15s - loss: 1.0936 - accuracy: 0.6788 - val_accuracy: 0.6470 - 15s/epoch - 0ms/step
# 23/40 - 15s - loss: 1.0795 - accuracy: 0.6834 - val_accuracy: 0.6600 - 15s/epoch - 0ms/step
# 24/40 - 15s - loss: 1.0631 - accuracy: 0.6907 - val_accuracy: 0.6658 - 15s/epoch - 0ms/step
# 25/40 - 15s - loss: 1.0378 - accuracy: 0.6978 - val_accuracy: 0.6732 - 15s/epoch - 0ms/step
# 26/40 - 15s - loss: 1.0213 - accuracy: 0.7075 - val_accuracy: 0.6804 - 15s/epoch - 0ms/step
# 27/40 - 15s - loss: 1.0134 - accuracy: 0.7093 - val_accuracy: 0.6728 - 15s/epoch - 0ms/step
# 28/40 - 15s - loss: 1.0027 - accuracy: 0.7113 - val_accuracy: 0.6830 - 15s/epoch - 0ms/step
# 29/40 - 15s - loss: 0.9815 - accuracy: 0.7195 - val_accuracy: 0.6902 - 15s/epoch - 0ms/step
# 30/40 - 15s - loss: 0.9666 - accuracy: 0.7243 - val_accuracy: 0.6800 - 15s/epoch - 0ms/step
# 31/40 - 15s - loss: 0.9665 - accuracy: 0.7258 - val_accuracy: 0.6800 - 15s/epoch - 0ms/step
# 32/40 - 15s - loss: 0.9526 - accuracy: 0.7318 - val_accuracy: 0.6802 - 15s/epoch - 0ms/step
# 33/40 - 15s - loss: 0.9328 - accuracy: 0.7378 - val_accuracy: 0.6924 - 15s/epoch - 0ms/step
# 34/40 - 14s - loss: 0.9194 - accuracy: 0.7418 - val_accuracy: 0.6920 - 14s/epoch - 0ms/step
# 35/40 - 15s - loss: 0.9162 - accuracy: 0.7440 - val_accuracy: 0.6938 - 15s/epoch - 0ms/step
# 36/40 - 14s - loss: 0.9137 - accuracy: 0.7411 - val_accuracy: 0.6828 - 14s/epoch - 0ms/step
# 37/40 - 15s - loss: 0.8888 - accuracy: 0.7525 - val_accuracy: 0.7042 - 15s/epoch - 0ms/step
# 38/40 - 15s - loss: 0.8791 - accuracy: 0.7549 - val_accuracy: 0.6884 - 15s/epoch - 0ms/step
# 39/40 - 15s - loss: 0.8676 - accuracy: 0.7603 - val_accuracy: 0.7022 - 15s/epoch - 0ms/step
# 40/40 - 14s - loss: 0.8607 - accuracy: 0.7628 - val_accuracy: 0.6914 - 14s/epoch - 0ms/step
# Time 583.1 sec
#
#
#
#
# ####### Training with asymmetric noise level: 0.1 ########
# Files already downloaded and verified
# asy:  50000   0.1
# 1/40 - 15s - loss: 2.3011 - accuracy: 0.1075 - val_accuracy: 0.1078 - 15s/epoch - 0ms/step
# 2/40 - 15s - loss: 2.3011 - accuracy: 0.1082 - val_accuracy: 0.1078 - 15s/epoch - 0ms/step
# 3/40 - 14s - loss: 2.3001 - accuracy: 0.1110 - val_accuracy: 0.1438 - 14s/epoch - 0ms/step
# 4/40 - 15s - loss: 2.0151 - accuracy: 0.1973 - val_accuracy: 0.2262 - 15s/epoch - 0ms/step
# 5/40 - 14s - loss: 1.8129 - accuracy: 0.2857 - val_accuracy: 0.3456 - 14s/epoch - 0ms/step
# 6/40 - 15s - loss: 1.6428 - accuracy: 0.3689 - val_accuracy: 0.4044 - 15s/epoch - 0ms/step
# 7/40 - 14s - loss: 1.4845 - accuracy: 0.4347 - val_accuracy: 0.4716 - 14s/epoch - 0ms/step
# 8/40 - 15s - loss: 1.3376 - accuracy: 0.5091 - val_accuracy: 0.5254 - 15s/epoch - 0ms/step
# 9/40 - 15s - loss: 1.1955 - accuracy: 0.5675 - val_accuracy: 0.5722 - 15s/epoch - 0ms/step
# 10/40 - 15s - loss: 1.1227 - accuracy: 0.5966 - val_accuracy: 0.6086 - 15s/epoch - 0ms/step
# 11/40 - 15s - loss: 1.0612 - accuracy: 0.6196 - val_accuracy: 0.6188 - 15s/epoch - 0ms/step
# 12/40 - 15s - loss: 1.0110 - accuracy: 0.6410 - val_accuracy: 0.6358 - 15s/epoch - 0ms/step
# 13/40 - 15s - loss: 0.9517 - accuracy: 0.6618 - val_accuracy: 0.6598 - 15s/epoch - 0ms/step
# 14/40 - 15s - loss: 0.9065 - accuracy: 0.6823 - val_accuracy: 0.6556 - 15s/epoch - 0ms/step
# 15/40 - 15s - loss: 0.8751 - accuracy: 0.6919 - val_accuracy: 0.6798 - 15s/epoch - 0ms/step
# 16/40 - 15s - loss: 0.8653 - accuracy: 0.6958 - val_accuracy: 0.6750 - 15s/epoch - 0ms/step
# 17/40 - 15s - loss: 0.8091 - accuracy: 0.7182 - val_accuracy: 0.7056 - 15s/epoch - 0ms/step
# 18/40 - 15s - loss: 0.7928 - accuracy: 0.7255 - val_accuracy: 0.7102 - 15s/epoch - 0ms/step
# 19/40 - 15s - loss: 0.7708 - accuracy: 0.7316 - val_accuracy: 0.7060 - 15s/epoch - 0ms/step
# 20/40 - 15s - loss: 0.7560 - accuracy: 0.7370 - val_accuracy: 0.7084 - 15s/epoch - 0ms/step
# 21/40 - 15s - loss: 0.7296 - accuracy: 0.7475 - val_accuracy: 0.7112 - 15s/epoch - 0ms/step
# 22/40 - 14s - loss: 0.7033 - accuracy: 0.7557 - val_accuracy: 0.7210 - 14s/epoch - 0ms/step
# 23/40 - 15s - loss: 0.6995 - accuracy: 0.7548 - val_accuracy: 0.7210 - 15s/epoch - 0ms/step
# 24/40 - 15s - loss: 0.6814 - accuracy: 0.7617 - val_accuracy: 0.7298 - 15s/epoch - 0ms/step
# 25/40 - 15s - loss: 0.6564 - accuracy: 0.7718 - val_accuracy: 0.7176 - 15s/epoch - 0ms/step
# 26/40 - 15s - loss: 0.6445 - accuracy: 0.7753 - val_accuracy: 0.7274 - 15s/epoch - 0ms/step
# 27/40 - 15s - loss: 0.6430 - accuracy: 0.7749 - val_accuracy: 0.7374 - 15s/epoch - 0ms/step
# 28/40 - 15s - loss: 0.6317 - accuracy: 0.7788 - val_accuracy: 0.7268 - 15s/epoch - 0ms/step
# 29/40 - 15s - loss: 0.6073 - accuracy: 0.7878 - val_accuracy: 0.7346 - 15s/epoch - 0ms/step
# 30/40 - 15s - loss: 0.6015 - accuracy: 0.7909 - val_accuracy: 0.7318 - 15s/epoch - 0ms/step
# 31/40 - 15s - loss: 0.5893 - accuracy: 0.7931 - val_accuracy: 0.7372 - 15s/epoch - 0ms/step
# 32/40 - 15s - loss: 0.5804 - accuracy: 0.7976 - val_accuracy: 0.7392 - 15s/epoch - 0ms/step
# 33/40 - 14s - loss: 0.5567 - accuracy: 0.8079 - val_accuracy: 0.7432 - 14s/epoch - 0ms/step
# 34/40 - 15s - loss: 0.5515 - accuracy: 0.8072 - val_accuracy: 0.7312 - 15s/epoch - 0ms/step
# 35/40 - 15s - loss: 0.5497 - accuracy: 0.8081 - val_accuracy: 0.7428 - 15s/epoch - 0ms/step
# 36/40 - 15s - loss: 0.5467 - accuracy: 0.8100 - val_accuracy: 0.7442 - 15s/epoch - 0ms/step
# 37/40 - 15s - loss: 0.5231 - accuracy: 0.8164 - val_accuracy: 0.7460 - 15s/epoch - 0ms/step
# 38/40 - 14s - loss: 0.5136 - accuracy: 0.8208 - val_accuracy: 0.7422 - 14s/epoch - 0ms/step
# 39/40 - 15s - loss: 0.5129 - accuracy: 0.8201 - val_accuracy: 0.7414 - 15s/epoch - 0ms/step
# 40/40 - 15s - loss: 0.4974 - accuracy: 0.8261 - val_accuracy: 0.7374 - 15s/epoch - 0ms/step
# Time 583.8 sec

# %%
noise_types = ['symmetric', 'asymmetric']
for noise_type in noise_types:
    noise_level = 0.3
    print(f"####### Training with {noise_type} noise level: {noise_level} ########")
    run_train_harness(noise_level, noise_type)
    print("\n\n\n")
# Out:
# ####### Training with symmetric noise level: 0.3 ########
# Files already downloaded and verified
# 1/40 - 15s - loss: 2.3042 - accuracy: 0.0994 - val_accuracy: 0.1058 - 15s/epoch - 0ms/step
# 2/40 - 14s - loss: 2.3037 - accuracy: 0.0988 - val_accuracy: 0.0994 - 14s/epoch - 0ms/step
# 3/40 - 15s - loss: 2.3037 - accuracy: 0.1003 - val_accuracy: 0.1020 - 15s/epoch - 0ms/step
# 4/40 - 15s - loss: 2.3037 - accuracy: 0.1000 - val_accuracy: 0.0960 - 15s/epoch - 0ms/step
# 5/40 - 15s - loss: 2.3034 - accuracy: 0.1006 - val_accuracy: 0.0994 - 15s/epoch - 0ms/step
# 6/40 - 15s - loss: 2.3025 - accuracy: 0.1030 - val_accuracy: 0.1084 - 15s/epoch - 0ms/step
# 7/40 - 14s - loss: 2.2167 - accuracy: 0.1537 - val_accuracy: 0.1782 - 14s/epoch - 0ms/step
# 8/40 - 15s - loss: 2.1418 - accuracy: 0.1918 - val_accuracy: 0.2086 - 15s/epoch - 0ms/step
# 9/40 - 15s - loss: 2.0773 - accuracy: 0.2379 - val_accuracy: 0.2446 - 15s/epoch - 0ms/step
# 10/40 - 15s - loss: 2.0407 - accuracy: 0.2701 - val_accuracy: 0.2900 - 15s/epoch - 0ms/step
# 11/40 - 15s - loss: 1.9802 - accuracy: 0.3102 - val_accuracy: 0.2980 - 15s/epoch - 0ms/step
# 12/40 - 14s - loss: 1.9350 - accuracy: 0.3465 - val_accuracy: 0.3654 - 14s/epoch - 0ms/step
# 13/40 - 15s - loss: 1.8835 - accuracy: 0.3761 - val_accuracy: 0.3944 - 15s/epoch - 0ms/step
# 14/40 - 15s - loss: 1.8445 - accuracy: 0.4018 - val_accuracy: 0.4048 - 15s/epoch - 0ms/step
# 15/40 - 15s - loss: 1.8182 - accuracy: 0.4148 - val_accuracy: 0.4296 - 15s/epoch - 0ms/step
# 16/40 - 15s - loss: 1.7962 - accuracy: 0.4294 - val_accuracy: 0.4358 - 15s/epoch - 0ms/step
# 17/40 - 14s - loss: 1.7634 - accuracy: 0.4464 - val_accuracy: 0.4378 - 14s/epoch - 0ms/step
# 18/40 - 14s - loss: 1.7441 - accuracy: 0.4565 - val_accuracy: 0.4566 - 14s/epoch - 0ms/step
# 19/40 - 15s - loss: 1.7197 - accuracy: 0.4716 - val_accuracy: 0.4584 - 15s/epoch - 0ms/step
# 20/40 - 15s - loss: 1.7029 - accuracy: 0.4810 - val_accuracy: 0.4774 - 15s/epoch - 0ms/step
# 21/40 - 15s - loss: 1.6778 - accuracy: 0.4915 - val_accuracy: 0.4862 - 15s/epoch - 0ms/step
# 22/40 - 14s - loss: 1.6729 - accuracy: 0.4961 - val_accuracy: 0.4870 - 14s/epoch - 0ms/step
# 23/40 - 15s - loss: 1.6518 - accuracy: 0.5061 - val_accuracy: 0.4852 - 15s/epoch - 0ms/step
# 24/40 - 15s - loss: 1.6431 - accuracy: 0.5104 - val_accuracy: 0.4894 - 15s/epoch - 0ms/step
# 25/40 - 15s - loss: 1.6222 - accuracy: 0.5210 - val_accuracy: 0.4936 - 15s/epoch - 0ms/step
# 26/40 - 15s - loss: 1.6135 - accuracy: 0.5242 - val_accuracy: 0.4872 - 15s/epoch - 0ms/step
# 27/40 - 14s - loss: 1.6031 - accuracy: 0.5288 - val_accuracy: 0.4878 - 14s/epoch - 0ms/step
# 28/40 - 15s - loss: 1.5944 - accuracy: 0.5344 - val_accuracy: 0.5046 - 15s/epoch - 0ms/step
# 29/40 - 15s - loss: 1.5752 - accuracy: 0.5426 - val_accuracy: 0.5138 - 15s/epoch - 0ms/step
# 30/40 - 15s - loss: 1.5696 - accuracy: 0.5452 - val_accuracy: 0.5088 - 15s/epoch - 0ms/step
# 31/40 - 15s - loss: 1.5617 - accuracy: 0.5480 - val_accuracy: 0.5024 - 15s/epoch - 0ms/step
# 32/40 - 15s - loss: 1.5537 - accuracy: 0.5505 - val_accuracy: 0.4996 - 15s/epoch - 0ms/step
# 33/40 - 15s - loss: 1.5379 - accuracy: 0.5596 - val_accuracy: 0.5052 - 15s/epoch - 0ms/step
# 34/40 - 15s - loss: 1.5301 - accuracy: 0.5590 - val_accuracy: 0.5026 - 15s/epoch - 0ms/step
# 35/40 - 15s - loss: 1.5223 - accuracy: 0.5652 - val_accuracy: 0.5058 - 15s/epoch - 0ms/step
# 36/40 - 15s - loss: 1.5186 - accuracy: 0.5640 - val_accuracy: 0.4998 - 15s/epoch - 0ms/step
# 37/40 - 14s - loss: 1.5060 - accuracy: 0.5707 - val_accuracy: 0.5108 - 14s/epoch - 0ms/step
# 38/40 - 15s - loss: 1.4929 - accuracy: 0.5748 - val_accuracy: 0.5190 - 15s/epoch - 0ms/step
# 39/40 - 15s - loss: 1.4901 - accuracy: 0.5748 - val_accuracy: 0.5102 - 15s/epoch - 0ms/step
# 40/40 - 15s - loss: 1.4872 - accuracy: 0.5761 - val_accuracy: 0.5136 - 15s/epoch - 0ms/step
# Time 583.9 sec
#
#
#
#
# ####### Training with asymmetric noise level: 0.3 ########
# Files already downloaded and verified
# asy:  50000   0.3
# 1/40 - 15s - loss: 2.2769 - accuracy: 0.1317 - val_accuracy: 0.1292 - 15s/epoch - 0ms/step
# 2/40 - 14s - loss: 2.2759 - accuracy: 0.1316 - val_accuracy: 0.1284 - 14s/epoch - 0ms/step
# 3/40 - 15s - loss: 2.2758 - accuracy: 0.1312 - val_accuracy: 0.1292 - 15s/epoch - 0ms/step
# 4/40 - 15s - loss: 2.2754 - accuracy: 0.1321 - val_accuracy: 0.1346 - 15s/epoch - 0ms/step
# 5/40 - 15s - loss: 2.1817 - accuracy: 0.1739 - val_accuracy: 0.2250 - 15s/epoch - 0ms/step
# 6/40 - 15s - loss: 1.8369 - accuracy: 0.2975 - val_accuracy: 0.3390 - 15s/epoch - 0ms/step
# 7/40 - 14s - loss: 1.6439 - accuracy: 0.3822 - val_accuracy: 0.4472 - 14s/epoch - 0ms/step
# 8/40 - 15s - loss: 1.4640 - accuracy: 0.4512 - val_accuracy: 0.4742 - 15s/epoch - 0ms/step
# 9/40 - 15s - loss: 1.3271 - accuracy: 0.4997 - val_accuracy: 0.5366 - 15s/epoch - 0ms/step
# 10/40 - 15s - loss: 1.2187 - accuracy: 0.5368 - val_accuracy: 0.5412 - 15s/epoch - 0ms/step
# 11/40 - 15s - loss: 1.1487 - accuracy: 0.5638 - val_accuracy: 0.5712 - 15s/epoch - 0ms/step
# 12/40 - 14s - loss: 1.1036 - accuracy: 0.5781 - val_accuracy: 0.5834 - 14s/epoch - 0ms/step
# 13/40 - 15s - loss: 1.0305 - accuracy: 0.6034 - val_accuracy: 0.5990 - 15s/epoch - 0ms/step
# 14/40 - 15s - loss: 0.9951 - accuracy: 0.6127 - val_accuracy: 0.6264 - 15s/epoch - 0ms/step
# 15/40 - 15s - loss: 0.9711 - accuracy: 0.6229 - val_accuracy: 0.6318 - 15s/epoch - 0ms/step
# 16/40 - 14s - loss: 0.9427 - accuracy: 0.6299 - val_accuracy: 0.6256 - 14s/epoch - 0ms/step
# 17/40 - 14s - loss: 0.9128 - accuracy: 0.6400 - val_accuracy: 0.6382 - 14s/epoch - 0ms/step
# 18/40 - 15s - loss: 0.8863 - accuracy: 0.6504 - val_accuracy: 0.6348 - 15s/epoch - 0ms/step
# 19/40 - 15s - loss: 0.8725 - accuracy: 0.6546 - val_accuracy: 0.6424 - 15s/epoch - 0ms/step
# 20/40 - 15s - loss: 0.8461 - accuracy: 0.6647 - val_accuracy: 0.6468 - 15s/epoch - 0ms/step
# 21/40 - 15s - loss: 0.8263 - accuracy: 0.6707 - val_accuracy: 0.6486 - 15s/epoch - 0ms/step
# 22/40 - 15s - loss: 0.8082 - accuracy: 0.6791 - val_accuracy: 0.6470 - 15s/epoch - 0ms/step
# 23/40 - 15s - loss: 0.7921 - accuracy: 0.6839 - val_accuracy: 0.6538 - 15s/epoch - 0ms/step
# 24/40 - 15s - loss: 0.7786 - accuracy: 0.6893 - val_accuracy: 0.6550 - 15s/epoch - 0ms/step
# 25/40 - 15s - loss: 0.7656 - accuracy: 0.6934 - val_accuracy: 0.6612 - 15s/epoch - 0ms/step
# 26/40 - 15s - loss: 0.7437 - accuracy: 0.7010 - val_accuracy: 0.6656 - 15s/epoch - 0ms/step
# 27/40 - 15s - loss: 0.7405 - accuracy: 0.7037 - val_accuracy: 0.6814 - 15s/epoch - 0ms/step
# 28/40 - 14s - loss: 0.7298 - accuracy: 0.7063 - val_accuracy: 0.6842 - 14s/epoch - 0ms/step
# 29/40 - 15s - loss: 0.7083 - accuracy: 0.7154 - val_accuracy: 0.6640 - 15s/epoch - 0ms/step
# 30/40 - 15s - loss: 0.7017 - accuracy: 0.7148 - val_accuracy: 0.6828 - 15s/epoch - 0ms/step
# 31/40 - 15s - loss: 0.6951 - accuracy: 0.7178 - val_accuracy: 0.6780 - 15s/epoch - 0ms/step
# 32/40 - 15s - loss: 0.6851 - accuracy: 0.7220 - val_accuracy: 0.6786 - 15s/epoch - 0ms/step
# 33/40 - 15s - loss: 0.6710 - accuracy: 0.7260 - val_accuracy: 0.6864 - 15s/epoch - 0ms/step
# 34/40 - 15s - loss: 0.6610 - accuracy: 0.7292 - val_accuracy: 0.6886 - 15s/epoch - 0ms/step
# 35/40 - 15s - loss: 0.6491 - accuracy: 0.7327 - val_accuracy: 0.6870 - 15s/epoch - 0ms/step
# 36/40 - 15s - loss: 0.6470 - accuracy: 0.7344 - val_accuracy: 0.6860 - 15s/epoch - 0ms/step
# 37/40 - 15s - loss: 0.6325 - accuracy: 0.7400 - val_accuracy: 0.6832 - 15s/epoch - 0ms/step
# 38/40 - 15s - loss: 0.6285 - accuracy: 0.7410 - val_accuracy: 0.6832 - 15s/epoch - 0ms/step
# 39/40 - 15s - loss: 0.6148 - accuracy: 0.7450 - val_accuracy: 0.6846 - 15s/epoch - 0ms/step
# 40/40 - 15s - loss: 0.6145 - accuracy: 0.7470 - val_accuracy: 0.6994 - 15s/epoch - 0ms/step
# Time 583.9 sec

# %%
noise_types = ['symmetric', 'asymmetric']
for noise_type in noise_types:
    noise_level = 0.5
    print(f"####### Training with {noise_type} noise level: {noise_level} ########")
    run_train_harness(noise_level, noise_type)
    print("\n\n\n")
# Out:
# ####### Training with symmetric noise level: 0.5 ########
# Files already downloaded and verified
# 1/40 - 15s - loss: 2.3040 - accuracy: 0.1008 - val_accuracy: 0.1060 - 15s/epoch - 0ms/step
# 2/40 - 17s - loss: 2.3039 - accuracy: 0.0991 - val_accuracy: 0.0956 - 17s/epoch - 0ms/step
# 3/40 - 15s - loss: 2.3036 - accuracy: 0.1014 - val_accuracy: 0.0940 - 15s/epoch - 0ms/step
# 4/40 - 15s - loss: 2.3036 - accuracy: 0.1007 - val_accuracy: 0.1004 - 15s/epoch - 0ms/step
# 5/40 - 15s - loss: 2.3035 - accuracy: 0.1004 - val_accuracy: 0.1106 - 15s/epoch - 0ms/step
# 6/40 - 15s - loss: 2.3035 - accuracy: 0.0989 - val_accuracy: 0.1004 - 15s/epoch - 0ms/step
# 7/40 - 15s - loss: 2.3033 - accuracy: 0.1008 - val_accuracy: 0.1060 - 15s/epoch - 0ms/step
# 8/40 - 15s - loss: 2.3033 - accuracy: 0.1003 - val_accuracy: 0.1020 - 15s/epoch - 0ms/step
# 9/40 - 15s - loss: 2.3032 - accuracy: 0.1013 - val_accuracy: 0.1060 - 15s/epoch - 0ms/step
# 10/40 - 15s - loss: 2.3032 - accuracy: 0.0986 - val_accuracy: 0.1106 - 15s/epoch - 0ms/step
# 11/40 - 15s - loss: 2.3031 - accuracy: 0.0999 - val_accuracy: 0.1106 - 15s/epoch - 0ms/step
# 12/40 - 15s - loss: 2.3032 - accuracy: 0.1029 - val_accuracy: 0.0986 - 15s/epoch - 0ms/step
# 13/40 - 15s - loss: 2.3031 - accuracy: 0.0990 - val_accuracy: 0.1004 - 15s/epoch - 0ms/step
# 14/40 - 15s - loss: 2.3031 - accuracy: 0.1020 - val_accuracy: 0.1060 - 15s/epoch - 0ms/step
# 15/40 - 14s - loss: 2.3032 - accuracy: 0.0999 - val_accuracy: 0.0940 - 14s/epoch - 0ms/step
# 16/40 - 15s - loss: 2.3029 - accuracy: 0.0997 - val_accuracy: 0.1106 - 15s/epoch - 0ms/step
# 17/40 - 15s - loss: 2.3030 - accuracy: 0.0992 - val_accuracy: 0.1012 - 15s/epoch - 0ms/step
# 18/40 - 14s - loss: 2.3029 - accuracy: 0.0997 - val_accuracy: 0.0964 - 14s/epoch - 0ms/step
# 19/40 - 15s - loss: 2.3030 - accuracy: 0.0970 - val_accuracy: 0.1004 - 15s/epoch - 0ms/step
# 20/40 - 15s - loss: 2.3030 - accuracy: 0.1023 - val_accuracy: 0.1106 - 15s/epoch - 0ms/step
# 21/40 - 14s - loss: 2.3028 - accuracy: 0.1012 - val_accuracy: 0.0986 - 14s/epoch - 0ms/step
# 22/40 - 15s - loss: 2.2992 - accuracy: 0.1128 - val_accuracy: 0.1308 - 15s/epoch - 0ms/step
# 23/40 - 15s - loss: 2.2738 - accuracy: 0.1330 - val_accuracy: 0.1446 - 15s/epoch - 0ms/step
# 24/40 - 15s - loss: 2.2550 - accuracy: 0.1435 - val_accuracy: 0.1530 - 15s/epoch - 0ms/step
# 25/40 - 14s - loss: 2.2471 - accuracy: 0.1473 - val_accuracy: 0.1538 - 14s/epoch - 0ms/step
# 26/40 - 15s - loss: 2.2436 - accuracy: 0.1529 - val_accuracy: 0.1598 - 15s/epoch - 0ms/step
# 27/40 - 15s - loss: 2.2369 - accuracy: 0.1579 - val_accuracy: 0.1650 - 15s/epoch - 0ms/step
# 28/40 - 15s - loss: 2.2334 - accuracy: 0.1660 - val_accuracy: 0.1816 - 15s/epoch - 0ms/step
# 29/40 - 14s - loss: 2.2278 - accuracy: 0.1719 - val_accuracy: 0.1896 - 14s/epoch - 0ms/step
# 30/40 - 15s - loss: 2.2205 - accuracy: 0.1822 - val_accuracy: 0.1856 - 15s/epoch - 0ms/step
# 31/40 - 15s - loss: 2.2130 - accuracy: 0.1928 - val_accuracy: 0.2070 - 15s/epoch - 0ms/step
# 32/40 - 15s - loss: 2.2027 - accuracy: 0.1996 - val_accuracy: 0.2132 - 15s/epoch - 0ms/step
# 33/40 - 14s - loss: 2.1858 - accuracy: 0.2128 - val_accuracy: 0.2188 - 14s/epoch - 0ms/step
# 34/40 - 15s - loss: 2.1729 - accuracy: 0.2232 - val_accuracy: 0.2318 - 15s/epoch - 0ms/step
# 35/40 - 15s - loss: 2.1632 - accuracy: 0.2311 - val_accuracy: 0.2174 - 15s/epoch - 0ms/step
# 36/40 - 15s - loss: 2.1570 - accuracy: 0.2378 - val_accuracy: 0.2360 - 15s/epoch - 0ms/step
# 37/40 - 15s - loss: 2.1458 - accuracy: 0.2465 - val_accuracy: 0.2412 - 15s/epoch - 0ms/step
# 38/40 - 14s - loss: 2.1344 - accuracy: 0.2565 - val_accuracy: 0.2564 - 14s/epoch - 0ms/step
# 39/40 - 14s - loss: 2.1303 - accuracy: 0.2577 - val_accuracy: 0.2734 - 14s/epoch - 0ms/step
# 40/40 - 14s - loss: 2.1219 - accuracy: 0.2684 - val_accuracy: 0.2490 - 14s/epoch - 0ms/step
# Time 586.0 sec
#
#
#
#
# ####### Training with asymmetric noise level: 0.5 ########
# Files already downloaded and verified
# asy:  50000   0.5
# 1/40 - 15s - loss: 2.2305 - accuracy: 0.1459 - val_accuracy: 0.1502 - 15s/epoch - 0ms/step
# 2/40 - 15s - loss: 2.2283 - accuracy: 0.1473 - val_accuracy: 0.1502 - 15s/epoch - 0ms/step
# 3/40 - 14s - loss: 2.2280 - accuracy: 0.1508 - val_accuracy: 0.1502 - 14s/epoch - 0ms/step
# 4/40 - 14s - loss: 2.2273 - accuracy: 0.1503 - val_accuracy: 0.1502 - 14s/epoch - 0ms/step
# 5/40 - 15s - loss: 2.0707 - accuracy: 0.2171 - val_accuracy: 0.2722 - 15s/epoch - 0ms/step
# 6/40 - 14s - loss: 1.8015 - accuracy: 0.3192 - val_accuracy: 0.3774 - 14s/epoch - 0ms/step
# 7/40 - 15s - loss: 1.5918 - accuracy: 0.4150 - val_accuracy: 0.4442 - 15s/epoch - 0ms/step
# 8/40 - 14s - loss: 1.4274 - accuracy: 0.4822 - val_accuracy: 0.5232 - 14s/epoch - 0ms/step
# 9/40 - 15s - loss: 1.2774 - accuracy: 0.5276 - val_accuracy: 0.5594 - 15s/epoch - 0ms/step
# 10/40 - 15s - loss: 1.1862 - accuracy: 0.5556 - val_accuracy: 0.5602 - 15s/epoch - 0ms/step
# 11/40 - 15s - loss: 1.1311 - accuracy: 0.5688 - val_accuracy: 0.5734 - 15s/epoch - 0ms/step
# 12/40 - 15s - loss: 1.0758 - accuracy: 0.5841 - val_accuracy: 0.5862 - 15s/epoch - 0ms/step
# 13/40 - 14s - loss: 1.0196 - accuracy: 0.5952 - val_accuracy: 0.5978 - 14s/epoch - 0ms/step
# 14/40 - 14s - loss: 0.9864 - accuracy: 0.6065 - val_accuracy: 0.5950 - 14s/epoch - 0ms/step
# 15/40 - 14s - loss: 0.9554 - accuracy: 0.6116 - val_accuracy: 0.5888 - 14s/epoch - 0ms/step
# 16/40 - 14s - loss: 0.9373 - accuracy: 0.6201 - val_accuracy: 0.6082 - 14s/epoch - 0ms/step
# 17/40 - 15s - loss: 0.9051 - accuracy: 0.6253 - val_accuracy: 0.6262 - 15s/epoch - 0ms/step
# 18/40 - 14s - loss: 0.8820 - accuracy: 0.6316 - val_accuracy: 0.6114 - 14s/epoch - 0ms/step
# 19/40 - 14s - loss: 0.8683 - accuracy: 0.6364 - val_accuracy: 0.6128 - 14s/epoch - 0ms/step
# 20/40 - 14s - loss: 0.8505 - accuracy: 0.6373 - val_accuracy: 0.6248 - 14s/epoch - 0ms/step
# 21/40 - 15s - loss: 0.8199 - accuracy: 0.6463 - val_accuracy: 0.6368 - 15s/epoch - 0ms/step
# 22/40 - 15s - loss: 0.8150 - accuracy: 0.6450 - val_accuracy: 0.6320 - 15s/epoch - 0ms/step
# 23/40 - 14s - loss: 0.8013 - accuracy: 0.6515 - val_accuracy: 0.6280 - 14s/epoch - 0ms/step
# 24/40 - 14s - loss: 0.7916 - accuracy: 0.6512 - val_accuracy: 0.6346 - 14s/epoch - 0ms/step
# 25/40 - 15s - loss: 0.7613 - accuracy: 0.6629 - val_accuracy: 0.6420 - 15s/epoch - 0ms/step
# 26/40 - 15s - loss: 0.7535 - accuracy: 0.6623 - val_accuracy: 0.6434 - 15s/epoch - 0ms/step
# 27/40 - 14s - loss: 0.7367 - accuracy: 0.6679 - val_accuracy: 0.6410 - 14s/epoch - 0ms/step
# 28/40 - 15s - loss: 0.7407 - accuracy: 0.6666 - val_accuracy: 0.6284 - 15s/epoch - 0ms/step
# 29/40 - 14s - loss: 0.7217 - accuracy: 0.6692 - val_accuracy: 0.6242 - 14s/epoch - 0ms/step
# 30/40 - 15s - loss: 0.7137 - accuracy: 0.6737 - val_accuracy: 0.6326 - 15s/epoch - 0ms/step
# 31/40 - 15s - loss: 0.7073 - accuracy: 0.6768 - val_accuracy: 0.6408 - 15s/epoch - 0ms/step
# 32/40 - 15s - loss: 0.7034 - accuracy: 0.6753 - val_accuracy: 0.6382 - 15s/epoch - 0ms/step
# 33/40 - 15s - loss: 0.6774 - accuracy: 0.6861 - val_accuracy: 0.6382 - 15s/epoch - 0ms/step
# 34/40 - 15s - loss: 0.6761 - accuracy: 0.6866 - val_accuracy: 0.6504 - 15s/epoch - 0ms/step
# 35/40 - 15s - loss: 0.6712 - accuracy: 0.6844 - val_accuracy: 0.6444 - 15s/epoch - 0ms/step
# 36/40 - 15s - loss: 0.6577 - accuracy: 0.6880 - val_accuracy: 0.6394 - 15s/epoch - 0ms/step
# 37/40 - 15s - loss: 0.6467 - accuracy: 0.6971 - val_accuracy: 0.6422 - 15s/epoch - 0ms/step
# 38/40 - 15s - loss: 0.6427 - accuracy: 0.6949 - val_accuracy: 0.6400 - 15s/epoch - 0ms/step
# 39/40 - 15s - loss: 0.6329 - accuracy: 0.6981 - val_accuracy: 0.6466 - 15s/epoch - 0ms/step
# 40/40 - 14s - loss: 0.6277 - accuracy: 0.6991 - val_accuracy: 0.6334 - 14s/epoch - 0ms/step
# Time 581.4 sec

# %%
noise_types = ['symmetric', 'asymmetric']
for noise_type in noise_types:
    noise_level = 0.8
    print(f"####### Training with {noise_type} noise level: {noise_level} ########")
    run_train_harness(noise_level, noise_type)
    print("\n\n\n")
# Out:
# ####### Training with symmetric noise level: 0.8 ########
# Files already downloaded and verified
# 1/40 - 15s - loss: 2.3037 - accuracy: 0.1012 - val_accuracy: 0.0966 - 15s/epoch - 0ms/step
# 2/40 - 14s - loss: 2.3042 - accuracy: 0.1006 - val_accuracy: 0.1002 - 14s/epoch - 0ms/step
# 3/40 - 14s - loss: 2.3038 - accuracy: 0.0988 - val_accuracy: 0.0982 - 14s/epoch - 0ms/step
# 4/40 - 14s - loss: 2.3036 - accuracy: 0.0998 - val_accuracy: 0.0910 - 14s/epoch - 0ms/step
# 5/40 - 15s - loss: 2.3037 - accuracy: 0.0999 - val_accuracy: 0.0966 - 15s/epoch - 0ms/step
# 6/40 - 15s - loss: 2.3034 - accuracy: 0.0974 - val_accuracy: 0.0910 - 15s/epoch - 0ms/step
# 7/40 - 15s - loss: 2.3034 - accuracy: 0.0999 - val_accuracy: 0.0966 - 15s/epoch - 0ms/step
# 8/40 - 14s - loss: 2.3033 - accuracy: 0.0997 - val_accuracy: 0.0966 - 14s/epoch - 0ms/step
# 9/40 - 14s - loss: 2.3034 - accuracy: 0.0993 - val_accuracy: 0.0966 - 14s/epoch - 0ms/step
# 10/40 - 15s - loss: 2.3033 - accuracy: 0.1000 - val_accuracy: 0.1066 - 15s/epoch - 0ms/step
# 11/40 - 15s - loss: 2.3032 - accuracy: 0.0988 - val_accuracy: 0.1026 - 15s/epoch - 0ms/step
# 12/40 - 15s - loss: 2.3032 - accuracy: 0.1006 - val_accuracy: 0.1018 - 15s/epoch - 0ms/step
# 13/40 - 15s - loss: 2.3031 - accuracy: 0.0999 - val_accuracy: 0.1018 - 15s/epoch - 0ms/step
# 14/40 - 15s - loss: 2.3031 - accuracy: 0.0985 - val_accuracy: 0.0966 - 15s/epoch - 0ms/step
# 15/40 - 14s - loss: 2.3030 - accuracy: 0.0984 - val_accuracy: 0.0994 - 14s/epoch - 0ms/step
# 16/40 - 14s - loss: 2.3030 - accuracy: 0.1035 - val_accuracy: 0.1002 - 14s/epoch - 0ms/step
# 17/40 - 14s - loss: 2.3030 - accuracy: 0.0988 - val_accuracy: 0.0966 - 14s/epoch - 0ms/step
# 18/40 - 14s - loss: 2.3030 - accuracy: 0.1017 - val_accuracy: 0.0994 - 14s/epoch - 0ms/step
# 19/40 - 15s - loss: 2.3031 - accuracy: 0.0987 - val_accuracy: 0.0966 - 15s/epoch - 0ms/step
# 20/40 - 14s - loss: 2.3030 - accuracy: 0.1004 - val_accuracy: 0.0956 - 14s/epoch - 0ms/step
# 21/40 - 14s - loss: 2.3029 - accuracy: 0.1006 - val_accuracy: 0.0956 - 14s/epoch - 0ms/step
# 22/40 - 14s - loss: 2.3029 - accuracy: 0.0995 - val_accuracy: 0.1018 - 14s/epoch - 0ms/step
# 23/40 - 15s - loss: 2.3029 - accuracy: 0.0986 - val_accuracy: 0.0956 - 15s/epoch - 0ms/step
# 24/40 - 14s - loss: 2.3029 - accuracy: 0.0993 - val_accuracy: 0.0966 - 14s/epoch - 0ms/step
# 25/40 - 14s - loss: 2.3030 - accuracy: 0.0985 - val_accuracy: 0.1066 - 14s/epoch - 0ms/step
# 26/40 - 14s - loss: 2.3028 - accuracy: 0.1014 - val_accuracy: 0.1066 - 14s/epoch - 0ms/step
# 27/40 - 15s - loss: 2.3029 - accuracy: 0.0992 - val_accuracy: 0.0994 - 15s/epoch - 0ms/step
# 28/40 - 15s - loss: 2.3030 - accuracy: 0.0978 - val_accuracy: 0.0910 - 15s/epoch - 0ms/step
# 29/40 - 15s - loss: 2.3029 - accuracy: 0.0977 - val_accuracy: 0.1066 - 15s/epoch - 0ms/step
# 30/40 - 15s - loss: 2.3028 - accuracy: 0.0994 - val_accuracy: 0.0910 - 15s/epoch - 0ms/step
# 31/40 - 14s - loss: 2.3029 - accuracy: 0.0992 - val_accuracy: 0.1002 - 14s/epoch - 0ms/step
# 32/40 - 14s - loss: 2.3029 - accuracy: 0.1004 - val_accuracy: 0.1066 - 14s/epoch - 0ms/step
# 33/40 - 15s - loss: 2.3029 - accuracy: 0.1019 - val_accuracy: 0.1018 - 15s/epoch - 0ms/step
# 34/40 - 15s - loss: 2.3028 - accuracy: 0.0972 - val_accuracy: 0.0966 - 15s/epoch - 0ms/step
# 35/40 - 15s - loss: 2.3028 - accuracy: 0.0992 - val_accuracy: 0.0994 - 15s/epoch - 0ms/step
# 36/40 - 14s - loss: 2.3028 - accuracy: 0.0996 - val_accuracy: 0.0966 - 14s/epoch - 0ms/step
# 37/40 - 15s - loss: 2.3028 - accuracy: 0.0992 - val_accuracy: 0.1002 - 15s/epoch - 0ms/step
# 38/40 - 14s - loss: 2.3029 - accuracy: 0.0983 - val_accuracy: 0.1002 - 14s/epoch - 0ms/step
# 39/40 - 15s - loss: 2.3028 - accuracy: 0.0999 - val_accuracy: 0.0966 - 15s/epoch - 0ms/step
# 40/40 - 14s - loss: 2.3028 - accuracy: 0.1017 - val_accuracy: 0.1002 - 14s/epoch - 0ms/step
# Time 581.2 sec
#
#
#
#
# ####### Training with asymmetric noise level: 0.8 ########
# Files already downloaded and verified
# asy:  50000   0.8
# 1/40 - 15s - loss: 2.0963 - accuracy: 0.1794 - val_accuracy: 0.1726 - 15s/epoch - 0ms/step
# 2/40 - 15s - loss: 2.0895 - accuracy: 0.1837 - val_accuracy: 0.1848 - 15s/epoch - 0ms/step
# 3/40 - 14s - loss: 2.0540 - accuracy: 0.1985 - val_accuracy: 0.2994 - 14s/epoch - 0ms/step
# 4/40 - 14s - loss: 1.7563 - accuracy: 0.3258 - val_accuracy: 0.3844 - 14s/epoch - 0ms/step
# 5/40 - 15s - loss: 1.5348 - accuracy: 0.4352 - val_accuracy: 0.4568 - 15s/epoch - 0ms/step
# 6/40 - 14s - loss: 1.3656 - accuracy: 0.5126 - val_accuracy: 0.4904 - 14s/epoch - 0ms/step
# 7/40 - 15s - loss: 1.2350 - accuracy: 0.5668 - val_accuracy: 0.5996 - 15s/epoch - 0ms/step
# 8/40 - 15s - loss: 1.1210 - accuracy: 0.6088 - val_accuracy: 0.6152 - 15s/epoch - 0ms/step
# 9/40 - 15s - loss: 1.0463 - accuracy: 0.6330 - val_accuracy: 0.6414 - 15s/epoch - 0ms/step
# 10/40 - 15s - loss: 0.9905 - accuracy: 0.6487 - val_accuracy: 0.6666 - 15s/epoch - 0ms/step
# 11/40 - 15s - loss: 0.9570 - accuracy: 0.6641 - val_accuracy: 0.6652 - 15s/epoch - 0ms/step
# 12/40 - 15s - loss: 0.9140 - accuracy: 0.6767 - val_accuracy: 0.6786 - 15s/epoch - 0ms/step
# 13/40 - 14s - loss: 0.8785 - accuracy: 0.6895 - val_accuracy: 0.6870 - 14s/epoch - 0ms/step
# 14/40 - 15s - loss: 0.8472 - accuracy: 0.6998 - val_accuracy: 0.6916 - 15s/epoch - 0ms/step
# 15/40 - 15s - loss: 0.8405 - accuracy: 0.7031 - val_accuracy: 0.6874 - 15s/epoch - 0ms/step
# 16/40 - 15s - loss: 0.8136 - accuracy: 0.7136 - val_accuracy: 0.7020 - 15s/epoch - 0ms/step
# 17/40 - 14s - loss: 0.7769 - accuracy: 0.7234 - val_accuracy: 0.7098 - 14s/epoch - 0ms/step
# 18/40 - 14s - loss: 0.7642 - accuracy: 0.7268 - val_accuracy: 0.6962 - 14s/epoch - 0ms/step
# 19/40 - 14s - loss: 0.7526 - accuracy: 0.7310 - val_accuracy: 0.7050 - 14s/epoch - 0ms/step
# 20/40 - 15s - loss: 0.7395 - accuracy: 0.7379 - val_accuracy: 0.7034 - 15s/epoch - 0ms/step
# 21/40 - 15s - loss: 0.7135 - accuracy: 0.7433 - val_accuracy: 0.7304 - 15s/epoch - 0ms/step
# 22/40 - 15s - loss: 0.7004 - accuracy: 0.7473 - val_accuracy: 0.7206 - 15s/epoch - 0ms/step
# 23/40 - 15s - loss: 0.6985 - accuracy: 0.7486 - val_accuracy: 0.7126 - 15s/epoch - 0ms/step
# 24/40 - 15s - loss: 0.6820 - accuracy: 0.7540 - val_accuracy: 0.7114 - 15s/epoch - 0ms/step
# 25/40 - 15s - loss: 0.6582 - accuracy: 0.7634 - val_accuracy: 0.7284 - 15s/epoch - 0ms/step
# 26/40 - 15s - loss: 0.6516 - accuracy: 0.7655 - val_accuracy: 0.7224 - 15s/epoch - 0ms/step
# 27/40 - 15s - loss: 0.6444 - accuracy: 0.7661 - val_accuracy: 0.7304 - 15s/epoch - 0ms/step
# 28/40 - 15s - loss: 0.6360 - accuracy: 0.7674 - val_accuracy: 0.7284 - 15s/epoch - 0ms/step
# 29/40 - 15s - loss: 0.6176 - accuracy: 0.7753 - val_accuracy: 0.7294 - 15s/epoch - 0ms/step
# 30/40 - 15s - loss: 0.6120 - accuracy: 0.7788 - val_accuracy: 0.7310 - 15s/epoch - 0ms/step
# 31/40 - 15s - loss: 0.6076 - accuracy: 0.7778 - val_accuracy: 0.7312 - 15s/epoch - 0ms/step
# 32/40 - 15s - loss: 0.6015 - accuracy: 0.7797 - val_accuracy: 0.7326 - 15s/epoch - 0ms/step
# 33/40 - 15s - loss: 0.5844 - accuracy: 0.7854 - val_accuracy: 0.7266 - 15s/epoch - 0ms/step
# 34/40 - 15s - loss: 0.5758 - accuracy: 0.7901 - val_accuracy: 0.7366 - 15s/epoch - 0ms/step
# 35/40 - 15s - loss: 0.5692 - accuracy: 0.7909 - val_accuracy: 0.7308 - 15s/epoch - 0ms/step
# 36/40 - 15s - loss: 0.5655 - accuracy: 0.7914 - val_accuracy: 0.7332 - 15s/epoch - 0ms/step
# 37/40 - 15s - loss: 0.5492 - accuracy: 0.7975 - val_accuracy: 0.7354 - 15s/epoch - 0ms/step
# 38/40 - 14s - loss: 0.5446 - accuracy: 0.7989 - val_accuracy: 0.7370 - 14s/epoch - 0ms/step
# 39/40 - 15s - loss: 0.5426 - accuracy: 0.8009 - val_accuracy: 0.7326 - 15s/epoch - 0ms/step
# 40/40 - 15s - loss: 0.5388 - accuracy: 0.8002 - val_accuracy: 0.7436 - 15s/epoch - 0ms/step
# Time 582.0 sec

# %%
noise_types = ['asymmetric']
for noise_type in noise_types:
    noise_level = 0.8
    print(f"####### Training with {noise_type} noise level: {noise_level} ########")
    run_train_harness(noise_level, noise_type)
    print("\n\n\n")
# Out:
# ####### Training with asymmetric noise level: 0.8 ########
# Files already downloaded and verified
# asy:  50000   0.8
# 1/40 - 15s - loss: 2.0954 - accuracy: 0.1778 - val_accuracy: 0.1764 - 15s/epoch - 0ms/step
# 2/40 - 14s - loss: 2.0878 - accuracy: 0.1786 - val_accuracy: 0.1766 - 14s/epoch - 0ms/step
# 3/40 - 15s - loss: 2.0559 - accuracy: 0.2045 - val_accuracy: 0.2616 - 15s/epoch - 0ms/step
# 4/40 - 15s - loss: 1.7187 - accuracy: 0.3493 - val_accuracy: 0.4076 - 15s/epoch - 0ms/step
# 5/40 - 15s - loss: 1.4907 - accuracy: 0.4524 - val_accuracy: 0.4836 - 15s/epoch - 0ms/step
# 6/40 - 15s - loss: 1.3244 - accuracy: 0.5300 - val_accuracy: 0.5312 - 15s/epoch - 0ms/step
# 7/40 - 14s - loss: 1.2031 - accuracy: 0.5768 - val_accuracy: 0.5942 - 14s/epoch - 0ms/step
# 8/40 - 15s - loss: 1.1103 - accuracy: 0.6136 - val_accuracy: 0.6098 - 15s/epoch - 0ms/step
# 9/40 - 15s - loss: 1.0384 - accuracy: 0.6357 - val_accuracy: 0.6386 - 15s/epoch - 0ms/step
# 10/40 - 16s - loss: 0.9918 - accuracy: 0.6503 - val_accuracy: 0.6542 - 16s/epoch - 0ms/step
# 11/40 - 15s - loss: 0.9512 - accuracy: 0.6655 - val_accuracy: 0.6576 - 15s/epoch - 0ms/step
# 12/40 - 15s - loss: 0.9277 - accuracy: 0.6732 - val_accuracy: 0.6776 - 15s/epoch - 0ms/step
# 13/40 - 15s - loss: 0.8785 - accuracy: 0.6915 - val_accuracy: 0.7030 - 15s/epoch - 0ms/step
# 14/40 - 15s - loss: 0.8547 - accuracy: 0.6974 - val_accuracy: 0.6834 - 15s/epoch - 0ms/step
# 15/40 - 15s - loss: 0.8362 - accuracy: 0.7057 - val_accuracy: 0.7014 - 15s/epoch - 0ms/step
# 16/40 - 15s - loss: 0.8163 - accuracy: 0.7121 - val_accuracy: 0.7026 - 15s/epoch - 0ms/step
# 17/40 - 15s - loss: 0.7849 - accuracy: 0.7224 - val_accuracy: 0.7082 - 15s/epoch - 0ms/step
# 18/40 - 14s - loss: 0.7737 - accuracy: 0.7234 - val_accuracy: 0.7096 - 14s/epoch - 0ms/step
# 19/40 - 15s - loss: 0.7618 - accuracy: 0.7306 - val_accuracy: 0.7100 - 15s/epoch - 0ms/step
# 20/40 - 14s - loss: 0.7521 - accuracy: 0.7311 - val_accuracy: 0.7072 - 14s/epoch - 0ms/step
# 21/40 - 15s - loss: 0.7219 - accuracy: 0.7408 - val_accuracy: 0.7154 - 15s/epoch - 0ms/step
# 22/40 - 15s - loss: 0.7084 - accuracy: 0.7461 - val_accuracy: 0.7176 - 15s/epoch - 0ms/step
# 23/40 - 15s - loss: 0.6953 - accuracy: 0.7499 - val_accuracy: 0.7118 - 15s/epoch - 0ms/step
# 24/40 - 14s - loss: 0.6994 - accuracy: 0.7485 - val_accuracy: 0.7266 - 14s/epoch - 0ms/step
# 25/40 - 14s - loss: 0.6713 - accuracy: 0.7582 - val_accuracy: 0.7194 - 14s/epoch - 0ms/step
# 26/40 - 14s - loss: 0.6598 - accuracy: 0.7623 - val_accuracy: 0.7156 - 14s/epoch - 0ms/step
# 27/40 - 14s - loss: 0.6541 - accuracy: 0.7616 - val_accuracy: 0.7376 - 14s/epoch - 0ms/step
# 28/40 - 15s - loss: 0.6500 - accuracy: 0.7624 - val_accuracy: 0.7314 - 15s/epoch - 0ms/step
# 29/40 - 14s - loss: 0.6281 - accuracy: 0.7696 - val_accuracy: 0.7320 - 14s/epoch - 0ms/step
# 30/40 - 15s - loss: 0.6259 - accuracy: 0.7730 - val_accuracy: 0.7390 - 15s/epoch - 0ms/step
# 31/40 - 15s - loss: 0.6117 - accuracy: 0.7768 - val_accuracy: 0.7444 - 15s/epoch - 0ms/step
# 32/40 - 14s - loss: 0.6082 - accuracy: 0.7776 - val_accuracy: 0.7372 - 14s/epoch - 0ms/step
# 33/40 - 15s - loss: 0.5920 - accuracy: 0.7824 - val_accuracy: 0.7370 - 15s/epoch - 0ms/step
# 34/40 - 15s - loss: 0.5763 - accuracy: 0.7886 - val_accuracy: 0.7370 - 15s/epoch - 0ms/step
# 35/40 - 15s - loss: 0.5764 - accuracy: 0.7886 - val_accuracy: 0.7402 - 15s/epoch - 0ms/step
# 36/40 - 14s - loss: 0.5731 - accuracy: 0.7902 - val_accuracy: 0.7402 - 14s/epoch - 0ms/step
# 37/40 - 15s - loss: 0.5529 - accuracy: 0.7975 - val_accuracy: 0.7312 - 15s/epoch - 0ms/step
# 38/40 - 14s - loss: 0.5516 - accuracy: 0.7959 - val_accuracy: 0.7354 - 14s/epoch - 0ms/step
# 39/40 - 15s - loss: 0.5473 - accuracy: 0.7976 - val_accuracy: 0.7384 - 15s/epoch - 0ms/step
# 40/40 - 14s - loss: 0.5470 - accuracy: 0.7973 - val_accuracy: 0.7372 - 14s/epoch - 0ms/step
# Time 584.0 sec
